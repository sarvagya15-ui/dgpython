# %%
a = 'my name is sarvagya'

# %%
for i in a :
    print(i)
# Out:
# m
# y
#
# n
# a
# m
# e
#
# i
# s
#
# s
# a
# r
# v
# a
# g
# y
# a

# %%
a[1:6] # slicing
# Out:
# 'y nam'

# %%
b =  input("enter a string: ")
b[0:3]
# Out:
# '4'

# %%
b
# Out:
# '4'

# %%
b[0:10:2]
# Out:
# '4'

# %%
a.split()
# Out:
# ['my', 'name', 'is', 'sarvagya']

# %%
a.find("name")
# Out:
# 3

# %%
a+" "+b
# Out:
# 'my name is sarvagya 4'

# %%
print(a*5)
# Out:
# my name is sarvagyamy name is sarvagyamy name is sarvagyamy name is sarvagyamy name is sarvagya

# %%
enumerate(a)

# %%
a.upper()
# Out:
# 'MY NAME IS SARVAGYA'

# %%
a.lower()
# Out:
# 'my name is sarvagya'

# %%
a.capitalize()
# Out:
# 'My name is sarvagya'

# %%
a.title()
# Out:
# 'My Name Is Sarvagya'

# %%
a[:4]
# Out:
# 'my n'

# %%
a
# Out:
# 'my name is sarvagya'

# %%
poem = '''jhony jhony yes papa
eating shugar no papa
telling a lie 
open your mouth ha ha ha'''

# %%
poem.find('papa')
# Out:
# 16

# %%
poem.replace('papa','dady')
# Out:
# 'jhony jhony yes dady\neating shugar no dady\ntelling a lie \nopen your mouth ha ha ha'

# %%
poem1 = '''twinkle twinkle little star
how i wonder what you are 
world above you are so high
like a diamond in the sky'''

# %%
v = poem1.replace('twinkle','chamak chamak ve ')
print(v)
# Out:
# chamak chamak ve  chamak chamak ve  little star
# how i wonder what you are
# world above you are so high
# like a diamond in the sky

# %%
v.splitlines()
v.title()
# Out:
# 'Chamak Chamak Ve  Chamak Chamak Ve  Little Star\nHow I Wonder What You Are \nWorld Above You Are So High\nLike A Diamond In The Sky'
