# %%
a = 'my name is sarvagya'

# %%
for i in a :
    print(i)
# Out:
# m
# y
#
# n
# a
# m
# e
#
# i
# s
#
# s
# a
# r
# v
# a
# g
# y
# a

# %%
a[1:6] # slicing
# Out:
# 'y nam'

# %%
b =  input("enter a string: ")
b[0:3]
# Out:
# 'sar'

# %%
b
# Out:
# 'sarvagya'

# %%
b[0:10:2]
# Out:
# 'sray'

# %%
a.split()
# Out:
# ['my', 'name', 'is', 'sarvagya']

# %%
a.find("name")
# Out:
# 3

# %%
a+" "+b
# Out:
# 'my name is sarvagya sarvagya'

# %%
print(a*5)
# Out:
# my name is sarvagyamy name is sarvagyamy name is sarvagyamy name is sarvagyamy name is sarvagya

# %%
enumerate(a)

# %%
a.upper()
# Out:
# 'MY NAME IS SARVAGYA'

# %%
a.lower()
# Out:
# 'my name is sarvagya'

# %%
a.capitalize()
# Out:
# 'My name is sarvagya'

# %%
a.title()
# Out:
# 'My Name Is Sarvagya'
