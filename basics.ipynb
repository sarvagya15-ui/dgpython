# %%
print("mahakal vikral yeh kalon ka bhi kal")
print("har har mahadev jai mahakal")
# Out:
# mahakal vikral yeh kalon ka bhi kal
# har har mahadev jai mahakal

# %% [markdown]
# `heading`
# - h1
#     - h1.1
#     - h2.2
# - h2

# %%
a = 2
n = 9
Sum = a + n
print(Sum)
# Out:
# 11
