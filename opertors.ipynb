# %%
a = 420
n = 22
Sum = a + n
multi = a*n
sub = a - n
dev = a / n
exp = a**n
fd = a//n
m = a % n
print(Sum)
print(sub)
print(dev)
print(multi)
print(exp)
print(fd)
print (m)
# Out:
# 442
# 398
# 19.09090909090909
# 9240
# 5146173081328524007005376493534576640000000000000000000000
# 19
# 2

# %%
a+= 89
print(a)
# Out:
# 509

# %%
a > n and a == n-1
# Out:
# False

# %% [markdown]
# `in`
# - shows sequence persent

# %%
lst = [2,5,6,87,9]
87 in lst
# Out:
# True

# %% [markdown]
# `not in`
# - show sequence not present as true

# %%
98 not in lst
# Out:
# True
