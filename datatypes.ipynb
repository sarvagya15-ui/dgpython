# %%
a = 12
b = 5 
print(a+b)
# Out:
# 17

# %%
c = 453.98
d = 4896.54646
print(c+d)
# Out:
# 5350.526459999999

# %%
str = "hello  i  am rocky the king of kgf"
print(str)
# Out:
# hello  i  am rocky the king of kgf

# %%
e = '"4821565468496"'
print(e)
# Out:
# "4821565468496"

# %% [markdown]
# special data type

# %%
ls1 = [1,2,3,4,5,6]
ls1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
ls2 = [15,2,4,5,35,65]
ls2
# Out:
# [15, 2, 4, 5, 35, 65]

# %%
ls3 = ['apple','banana',"mango"]
ls3
# Out:
# ['apple', 'banana', 'mango']

# %%
ls3.append("guava")

# %%
ls3
# Out:
# ['apple', 'banana', 'mango', 'guava']

# %%
tuple1 = ("gta","cod","battle field","gta","cod")
tuple1
# Out:
# ('gta', 'cod', 'battle field', 'gta', 'cod')

# %%
165465+9564564
# Out:
# 9730029

# %%
student = {
    "name":"sarvagya",
    "city":"lucknow"}
student
# Out:
# {'name': 'sarvagya', 'city': 'lucknow'}

# %% [markdown]
# #type casting

# %%
a =  int(input(" input a number"))
b =  int(input(" enter number b"))
print(a + b)
print(f"sum of {a} and {b} is {a+b}")
# Out:
# 9451
# sumof8965and486is9451
